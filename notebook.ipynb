# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

columns = ["Algorithm", "Mean CPU", "Mean Core", "N/A", "N/A", "Time"]
folders = ["C", "Java", "Java-GraalVM", "JavaScript", "Python", "Rust"]
dataframes = {}

for folder in folders:
    file_path = os.path.join(folder, f"{folder}.csv")
    with open(file_path) as file:
        if folder == "Java":
            data = file.readlines()[1:]
            data = ''.join(data).replace(';',',')
        else:
            data = file.read().replace(';',',')
        data = ','.join(columns) + '\n' + data

        new_file_path = os.path.join(folder, f"{folder}_result.csv")
        with open(new_file_path, 'w') as new_file:
            new_file.write(data)

# %%
for folder in folders:
    file_path = os.path.join(folder, f"{folder}_result.csv")
    with open(file_path) as file:
        df = pd.read_csv(file_path, sep=',', dtype={col: 'float32' for col in range(1, 3)})  # Colonnes 1, 2 et 3 comme float32

        dataframes[folder] = df

# %%
mean_values = {}
sigma_values = {}

for folder, df in dataframes.items():
    mean_time_df = df.groupby("Algorithm")["Time"].mean()
    mean_cpu_df = df.groupby("Algorithm")["Mean CPU"].mean()

    mean_values[folder] = {}
    mean_values[folder]["Time"] = mean_time_df
    mean_values[folder]["Mean CPU"] = mean_cpu_df

    sigma_time_df = df.groupby("Algorithm")["Time"].std().astype("float32")
    sigma_cpu_df = df.groupby("Algorithm")["Mean CPU"].std().astype("float32")

    sigma_values[folder] = {}
    sigma_values[folder]["Sigma Time"] = sigma_time_df
    sigma_values[folder]["Sigma CPU"] = sigma_cpu_df

sigma_values
# Out:
# {'C': {'Sigma Time': Algorithm
#   binary-trees        10.046383
#   fannkuch-redux     101.513542
#   mandelbrot           4.173754
#   pidigits             7.222633
#   spectral-norm       41.162102
#   Name: Time, dtype: float32,
#   'Sigma CPU': Algorithm
#   binary-trees       1.032885
#   fannkuch-redux     9.618095
#   mandelbrot         1.574534
#   pidigits           0.713747
#   spectral-norm      1.861564
#   Name: Mean CPU, dtype: float32},
#  'Java': {'Sigma Time': Algorithm
#   binary-trees        29.343115
#   fannkuch-redux     239.970398
#   mandelbrot          27.706865
#   spectral-norm        4.730514
#   Name: Time, dtype: float32,
#   'Sigma CPU': Algorithm
#   binary-trees        2.028415
#   fannkuch-redux     19.373983
#   mandelbrot          1.527040
#   spectral-norm       0.228395
#   Name: Mean CPU, dtype: float32},
#  'Java-GraalVM': {'Sigma Time': Algorithm
#   binary-trees       58.034382
#   fannkuch-redux     77.265221
#   mandelbrot         25.192326
#   spectral-norm      35.687302
#   Name: Time, dtype: float32,
#   'Sigma CPU': Algorithm
#   binary-trees       3.381233
#   fannkuch-redux     5.089013
#   mandelbrot         2.161963
#   spectral-norm      2.008426
#   Name: Mean CPU, dtype: float32},
#  'JavaScript': {'Sigma Time': Algorithm
#   binary-trees       503.570770
#   fannkuch-redux     517.517456
#   mandelbrot         102.969994
#   spectral-norm       54.499359
#   Name: Time, dtype: float32,
#   'Sigma CPU': Algorithm
#   binary-trees       24.271202
#   fannkuch-redux     54.614742
#   mandelbrot          6.034960
#   spectral-norm       3.253727
#   Name: Mean CPU, dtype: float32},
#  'Python': {'Sigma Time': Algorithm
#   binary-trees        255.779190
#   fannkuch-redux     9289.590820
#   mandelbrot          667.992371
#   pidigits             18.071404
#   spectral-norm       687.414185
#   Name: Time, dtype: float32,
#   'Sigma CPU': Algorithm
#   binary-trees         44.723370
#   fannkuch-redux     1115.840820
#   mandelbrot           59.686844
#   pidigits              0.435476
#   spectral-norm        86.698982
#   Name: Mean CPU, dtype: float32},
#  'Rust': {'Sigma Time': Algorithm
#   binary-trees       33.318905
#   fannkuch-redux     53.198647
#   mandelbrot          7.430763
#   pidigits            3.758850
#   spectral-norm       7.318553
#   Name: Time, dtype: float32,
#   'Sigma CPU': Algorithm
#   binary-trees       0.871020
#   fannkuch-redux     2.591720
#   mandelbrot         0.596212
#   pidigits           0.878817
#   spectral-norm      0.177602
#   Name: Mean CPU, dtype: float32}}

# %%
with open('paper_results.csv') as file:
    paper_df = pd.read_csv(file, sep=',', dtype={col: 'float32' for col in range(2, 4)})

# %%
def plot_results(our_key, paper_key, df):
    for language in paper_df.groupby("Language").groups.keys():
        print(f"Language: {language}")
        print(f"Difference in {our_key} between paper and our results")
        for algorithm in df[language][our_key].keys():

            our_value = df[language][our_key][algorithm]
            paper_value = paper_df[(paper_df['Language'] == language) & (paper_df['Algorithm'] == algorithm)][paper_key].values[0]

            print(f"   Algorithm: {algorithm}")
            print(f"      Our mean: {our_value}")
            print(f"      Paper mean: {paper_value}")
            print(f"      Difference: {our_value - paper_value}")

        fig, ax = plt.subplots(figsize=(10, 6))

        our_times = [df[language][our_key][algorithm] for algorithm in df[language][our_key].keys()]
        paper_times = [paper_df[(paper_df['Language'] == language) & (paper_df['Algorithm'] == algorithm)][paper_key].values[0] for algorithm in df[language][our_key].keys()]
        algorithms = list(df[language][our_key].keys())

        ax.bar(algorithms, our_times, width=0.4, label='Our Results', align='center')
        ax.bar(algorithms, paper_times, width=0.4, label='Paper Results', align='edge')

        ax.set_xlabel('Algorithm')
        ax.set_ylabel(our_key)
        ax.set_title(f'Comparison of {our_key} for {language}')
        ax.legend()

        plt.xticks(rotation=45)
        plt.tight_layout()

        plt.show()

# %%
plot_results("Time", "MeanTime", mean_values)
# Out:
# Language: C
# Difference in Time between paper and our results
#    Algorithm: binary-trees
#       Our mean: 841.7207000000001
#       Paper mean: 1125
#       Difference: -283.2792999999999
#    Algorithm: fannkuch-redux
#       Our mean: 4330.302000000001
#       Paper mean: 6076
#       Difference: -1745.6979999999994
#    Algorithm: mandelbrot
#       Our mean: 760.6239
#       Paper mean: 1142
#       Difference: -381.37609999999995
#    Algorithm: pidigits
#       Our mean: 536.6787
#       Paper mean: 546
#       Difference: -9.321299999999951
#    Algorithm: spectral-norm
#       Our mean: 223.5433
#       Paper mean: 677
#       Difference: -453.4567
# Language: Java
# Difference in Time between paper and our results
#    Algorithm: binary-trees
#       Our mean: 2103.062
#       Paper mean: 3306
#       Difference: -1202.938
#    Algorithm: fannkuch-redux
#       Our mean: 6230.903
#       Paper mean: 8241
#       Difference: -2010.0969999999998
#    Algorithm: mandelbrot
#       Our mean: 1984.895
#       Paper mean: 3657
#       Difference: -1672.105
#    Algorithm: spectral-norm
#       Our mean: 752.6828
#       Paper mean: 1659
#       Difference: -906.3172
# Language: JavaScript
# Difference in Time between paper and our results
#    Algorithm: binary-trees
#       Our mean: 13348.34
#       Paper mean: 21349
#       Difference: -8000.66
#    Algorithm: fannkuch-redux
#       Our mean: 29182.920000000002
#       Paper mean: 33663
#       Difference: -4480.079999999998
#    Algorithm: mandelbrot
#       Our mean: 3646.5449999999996
#       Paper mean: 8278
#       Difference: -4631.455
#    Algorithm: spectral-norm
#       Our mean: 2564.517
#       Paper mean: 5048
#       Difference: -2483.483
# Language: Python
# Difference in Time between paper and our results
#    Algorithm: binary-trees
#       Our mean: 23754.23
#       Paper mean: 45003
#       Difference: -21248.77
#    Algorithm: fannkuch-redux
#       Our mean: 209302.3
#       Paper mean: 279544
#       Difference: -70241.70000000001
#    Algorithm: mandelbrot
#       Our mean: 117835.0
#       Paper mean: 163332
#       Difference: -45497.0
#    Algorithm: pidigits
#       Our mean: 87.523
#       Paper mean: 1191
#       Difference: -1103.477
#    Algorithm: spectral-norm
#       Our mean: 65749.01
#       Paper mean: 137738
#       Difference: -71988.99
# Language: Rust
# Difference in Time between paper and our results
#    Algorithm: binary-trees
#       Our mean: 935.0758
#       Paper mean: 1263
#       Difference: -327.92420000000004
#    Algorithm: fannkuch-redux
#       Our mean: 5243.518
#       Paper mean: 6628
#       Difference: -1384.482
#    Algorithm: mandelbrot
#       Our mean: 873.8617
#       Paper mean: 1179
#       Difference: -305.13829999999996
#    Algorithm: pidigits
#       Our mean: 635.897
#       Paper mean: 559
#       Difference: 76.89700000000005
#    Algorithm: spectral-norm
#       Our mean: 386.48560000000003
#       Paper mean: 677
#       Difference: -290.51439999999997

# %%
plot_results("Mean CPU", "MeanCPU", mean_values)
# Out:
# Language: C
# Difference in Mean CPU between paper and our results
#    Algorithm: binary-trees
#       Our mean: 41.69903564453125
#       Paper mean: 36.060001373291016
#       Difference: 5.639034271240234
#    Algorithm: fannkuch-redux
#       Our mean: 235.53189086914062
#       Paper mean: 201.11000061035156
#       Difference: 34.42189025878906
#    Algorithm: mandelbrot
#       Our mean: 41.93830108642578
#       Paper mean: 32.599998474121094
#       Difference: 9.338302612304688
#    Algorithm: pidigits
#       Our mean: 15.106878280639648
#       Paper mean: 6.190000057220459
#       Difference: 8.916877746582031
#    Algorithm: spectral-norm
#       Our mean: 12.598065376281738
#       Paper mean: 20.020000457763672
#       Difference: -7.421935081481934
# Language: Java
# Difference in Mean CPU between paper and our results
#    Algorithm: binary-trees
#       Our mean: 106.2367172241211
#       Paper mean: 96.08999633789062
#       Difference: 10.146720886230469
#    Algorithm: fannkuch-redux
#       Our mean: 373.7615051269531
#       Paper mean: 291.4599914550781
#       Difference: 82.301513671875
#    Algorithm: mandelbrot
#       Our mean: 109.92582702636719
#       Paper mean: 105.33999633789062
#       Difference: 4.5858306884765625
#    Algorithm: spectral-norm
#       Our mean: 30.305328369140625
#       Paper mean: 37.15999984741211
#       Difference: -6.854671478271484
# Language: JavaScript
# Difference in Mean CPU between paper and our results
#    Algorithm: binary-trees
#       Our mean: 437.4042053222656
#       Paper mean: 238.69000244140625
#       Difference: 198.71420288085938
#    Algorithm: fannkuch-redux
#       Our mean: 788.33740234375
#       Paper mean: 332.57000732421875
#       Difference: 455.76739501953125
#    Algorithm: mandelbrot
#       Our mean: 190.86715698242188
#       Paper mean: 211.33999633789062
#       Difference: -20.47283935546875
#    Algorithm: spectral-norm
#       Our mean: 66.89144897460938
#       Paper mean: 39.25
#       Difference: 27.641448974609375
# Language: Python
# Difference in Mean CPU between paper and our results
#    Algorithm: binary-trees
#       Our mean: 1082.523193359375
#       Paper mean: 1666.0899658203125
#       Difference: -583.5667724609375
#    Algorithm: fannkuch-redux
#       Our mean: 10504.7158203125
#       Paper mean: 12108.7197265625
#       Difference: -1604.00390625
#    Algorithm: mandelbrot
#       Our mean: 5311.77880859375
#       Paper mean: 7395.52001953125
#       Difference: -2083.7412109375
#    Algorithm: pidigits
#       Our mean: 2.284381151199341
#       Paper mean: 14.699999809265137
#       Difference: -12.415618896484375
#    Algorithm: spectral-norm
#       Our mean: 2986.136962890625
#       Paper mean: 6077.240234375
#       Difference: -3091.103271484375
# Language: Rust
# Difference in Mean CPU between paper and our results
#    Algorithm: binary-trees
#       Our mean: 31.6246395111084
#       Paper mean: 44.459999084472656
#       Difference: -12.835359573364258
#    Algorithm: fannkuch-redux
#       Our mean: 172.5490264892578
#       Paper mean: 222.2899932861328
#       Difference: -49.740966796875
#    Algorithm: mandelbrot
#       Our mean: 30.010589599609375
#       Paper mean: 38.2400016784668
#       Difference: -8.229412078857422
#    Algorithm: pidigits
#       Our mean: 9.75640869140625
#       Paper mean: 6.75
#       Difference: 3.00640869140625
#    Algorithm: spectral-norm
#       Our mean: 14.92291259765625
#       Paper mean: 22.729999542236328
#       Difference: -7.807086944580078

# %%
plot_results("Sigma Time", "SigmaTime", sigma_values)
# Out:
# Language: C
# Difference in Sigma Time between paper and our results
#    Algorithm: binary-trees
#       Our mean: 10.046382904052734
#       Paper mean: 5.76
#       Difference: 4.286382904052735
#    Algorithm: fannkuch-redux
#       Our mean: 101.51354217529297
#       Paper mean: 7.43
#       Difference: 94.08354217529296
#    Algorithm: mandelbrot
#       Our mean: 4.1737542152404785
#       Paper mean: 0.31
#       Difference: 3.8637542152404785
#    Algorithm: pidigits
#       Our mean: 7.222633361816406
#       Paper mean: 1.76
#       Difference: 5.4626333618164065
#    Algorithm: spectral-norm
#       Our mean: 41.16210174560547
#       Paper mean: 13.69
#       Difference: 27.47210174560547
# Language: Java
# Difference in Sigma Time between paper and our results
#    Algorithm: binary-trees
#       Our mean: 29.343114852905273
#       Paper mean: 33.58
#       Difference: -4.236885147094725
#    Algorithm: fannkuch-redux
#       Our mean: 239.97039794921875
#       Paper mean: 46.92
#       Difference: 193.05039794921873
#    Algorithm: mandelbrot
#       Our mean: 27.706865310668945
#       Paper mean: 13.85
#       Difference: 13.856865310668946
#    Algorithm: spectral-norm
#       Our mean: 4.730514049530029
#       Paper mean: 41.58
#       Difference: -36.84948595046997
# Language: JavaScript
# Difference in Sigma Time between paper and our results
#    Algorithm: binary-trees
#       Our mean: 503.5707702636719
#       Paper mean: 200.89
#       Difference: 302.6807702636719
#    Algorithm: fannkuch-redux
#       Our mean: 517.5174560546875
#       Paper mean: 17.53
#       Difference: 499.9874560546875
#    Algorithm: mandelbrot
#       Our mean: 102.9699935913086
#       Paper mean: 76.26
#       Difference: 26.70999359130859
#    Algorithm: spectral-norm
#       Our mean: 54.499359130859375
#       Paper mean: 23.21
#       Difference: 31.289359130859374
# Language: Python
# Difference in Sigma Time between paper and our results
#    Algorithm: binary-trees
#       Our mean: 255.77919006347656
#       Paper mean: 620.39
#       Difference: -364.6108099365234
#    Algorithm: fannkuch-redux
#       Our mean: 9289.5908203125
#       Paper mean: 1432.46
#       Difference: 7857.1308203125
#    Algorithm: mandelbrot
#       Our mean: 667.9923706054688
#       Paper mean: 2138.95
#       Difference: -1470.957629394531
#    Algorithm: pidigits
#       Our mean: 18.07140350341797
#       Paper mean: 34.99
#       Difference: -16.918596496582033
#    Algorithm: spectral-norm
#       Our mean: 687.4141845703125
#       Paper mean: 459.85
#       Difference: 227.56418457031248
# Language: Rust
# Difference in Sigma Time between paper and our results
#    Algorithm: binary-trees
#       Our mean: 33.318904876708984
#       Paper mean: 37.6
#       Difference: -4.281095123291017
#    Algorithm: fannkuch-redux
#       Our mean: 53.198646545410156
#       Paper mean: 31.21
#       Difference: 21.988646545410155
#    Algorithm: mandelbrot
#       Our mean: 7.430762767791748
#       Paper mean: 9.84
#       Difference: -2.409237232208252
#    Algorithm: pidigits
#       Our mean: 3.758849620819092
#       Paper mean: 22.12
#       Difference: -18.36115037918091
#    Algorithm: spectral-norm
#       Our mean: 7.318553447723389
#       Paper mean: 7.47
#       Difference: -0.15144655227661108

# %%
plot_results("Sigma CPU", "SigmaCPU", sigma_values)
# Out:
# Language: C
# Difference in Sigma CPU between paper and our results
#    Algorithm: binary-trees
#       Our mean: 1.0328848361968994
#       Paper mean: 0.07999999821186066
#       Difference: 0.9528848528862
#    Algorithm: fannkuch-redux
#       Our mean: 9.618095397949219
#       Paper mean: 1.2899999618530273
#       Difference: 8.328095436096191
#    Algorithm: mandelbrot
#       Our mean: 1.5745335817337036
#       Paper mean: 0.03999999910593033
#       Difference: 1.5345336198806763
#    Algorithm: pidigits
#       Our mean: 0.7137468457221985
#       Paper mean: 0.07999999821186066
#       Difference: 0.633746862411499
#    Algorithm: spectral-norm
#       Our mean: 1.861564040184021
#       Paper mean: 0.03999999910593033
#       Difference: 1.8215640783309937
# Language: Java
# Difference in Sigma CPU between paper and our results
#    Algorithm: binary-trees
#       Our mean: 2.0284154415130615
#       Paper mean: 0.8500000238418579
#       Difference: 1.1784154176712036
#    Algorithm: fannkuch-redux
#       Our mean: 19.37398338317871
#       Paper mean: 2.9700000286102295
#       Difference: 16.40398406982422
#    Algorithm: mandelbrot
#       Our mean: 1.5270403623580933
#       Paper mean: 0.27000001072883606
#       Difference: 1.2570403814315796
#    Algorithm: spectral-norm
#       Our mean: 0.2283952683210373
#       Paper mean: 0.8600000143051147
#       Difference: -0.6316047310829163
# Language: JavaScript
# Difference in Sigma CPU between paper and our results
#    Algorithm: binary-trees
#       Our mean: 24.271202087402344
#       Paper mean: 2.259999990463257
#       Difference: 22.011201858520508
#    Algorithm: fannkuch-redux
#       Our mean: 54.614742279052734
#       Paper mean: 0.2800000011920929
#       Difference: 54.33474349975586
#    Algorithm: mandelbrot
#       Our mean: 6.0349602699279785
#       Paper mean: 0.33000001311302185
#       Difference: 5.704960346221924
#    Algorithm: spectral-norm
#       Our mean: 3.2537269592285156
#       Paper mean: 0.10000000149011612
#       Difference: 3.1537270545959473
# Language: Python
# Difference in Sigma CPU between paper and our results
#    Algorithm: binary-trees
#       Our mean: 44.72336959838867
#       Paper mean: 10.25
#       Difference: 34.47336959838867
#    Algorithm: fannkuch-redux
#       Our mean: 1115.8408203125
#       Paper mean: 105.72000122070312
#       Difference: 1010.120849609375
#    Algorithm: mandelbrot
#       Our mean: 59.68684387207031
#       Paper mean: 48.130001068115234
#       Difference: 11.556842803955078
#    Algorithm: pidigits
#       Our mean: 0.4354763329029083
#       Paper mean: 0.23000000417232513
#       Difference: 0.2054763287305832
#    Algorithm: spectral-norm
#       Our mean: 86.69898223876953
#       Paper mean: 47.279998779296875
#       Difference: 39.418983459472656
# Language: Rust
# Difference in Sigma CPU between paper and our results
#    Algorithm: binary-trees
#       Our mean: 0.8710201978683472
#       Paper mean: 0.10999999940395355
#       Difference: 0.7610201835632324
#    Algorithm: fannkuch-redux
#       Our mean: 2.5917203426361084
#       Paper mean: 1.3200000524520874
#       Difference: 1.271720290184021
#    Algorithm: mandelbrot
#       Our mean: 0.5962123274803162
#       Paper mean: 0.03999999910593033
#       Difference: 0.556212306022644
#    Algorithm: pidigits
#       Our mean: 0.8788174390792847
#       Paper mean: 0.14000000059604645
#       Difference: 0.7388174533843994
#    Algorithm: spectral-norm
#       Our mean: 0.17760153114795685
#       Paper mean: 0.07999999821186066
#       Difference: 0.09760153293609619
